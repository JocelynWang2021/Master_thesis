# %%
from keras.utils import np_utils
from keras.models import Sequential
from keras.layers import Dense, LSTM, Dropout
from keras.callbacks import EarlyStopping
from sklearn.preprocessing import StandardScaler
from pandas import read_csv

import pandas as pd
import numpy as np
import glob
import matplotlib.pyplot as plt
import collections
# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %%
# Set up a 'look back' dataset for sequence to label prediction with Keras.

# The LSTM network expects the input data (X) to be provided with a specific
# array structure in the form of: [samples, time steps, features].

def create_dataset(X, Y, **options):
    """Convert an array of X, Y values into a dataset matrix for and LSTM"""
    
    look_back = options.pop('look_back', None)
    dataX, dataY = [], []
    for i in range(len(X) - look_back):
        a = X[i:(i+look_back)]
        dataX.append(a)
        dataY.append(Y[i + look_back - 1])
    return np.array(dataX), np.array(dataY)

# Predictions will be based on look_back minutes of data:
look_back = 50

# %%
Test_path = glob.glob('C:\\Users\\XWANG221\\Downloads\\Test_Flow_Trac\\*.csv')

X_TestData = np.empty((1, 50, 22))
Y_TestData = np.empty((1,))

for f in range(300):
    print(Test_path[f].split('/')[-1])
    
    Flow_Test = pd.read_csv(Test_path[f], usecols=['LatitudeWsu','GpsHeadingWsu','AxWsu','Flow','LaneDistanceLeft','LaneDistanceRight','LaneHeading','o1','o2','o6','o7','r1','r6','r7','rr6','rr7','t1','t6','t7','tt1','tt7','c1','c2'])
    Flow_Test.fillna(10000000, inplace=True)
    
    Y_train_Test = np.array(Flow_Test['Flow'].values)
    X_train_Test = np.array(Flow_Test[['LatitudeWsu','GpsHeadingWsu','AxWsu','LaneDistanceLeft','LaneDistanceRight','LaneHeading','o1','o2','o6','o7','r1','r6','r7','rr6','rr7','t1','t6','t7','tt1','tt7','c1','c2']])
    
    dimof_output = 1
    dimof_input = X_train_Test.shape[1]

    # Scale/whiten the X data
    scaler = StandardScaler()
    X_train_Test = scaler.fit_transform(X_train_Test)
    
    XTest, YTest = create_dataset(X_train_Test, Y_train_Test, look_back=look_back)
    
    X_TestData = np.append(X_TestData, XTest1, axis=0)
    Y_TestData = np.append(Y_TestData, YTest1, axis=0)
# Out:
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_0.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_10.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_100.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_102.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_104.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_106.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_108.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_110.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_112.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_114.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_116.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_118.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_12.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_120.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_122.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_124.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_126.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_128.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_130.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_132.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_134.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_136.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_138.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_14.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_140.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_142.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_144.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_146.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_148.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_150.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_152.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_154.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_156.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_158.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_16.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_160.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_162.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_164.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_166.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_168.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_170.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_172.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_174.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_176.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_178.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_18.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_180.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_182.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_184.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_186.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_188.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_190.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_192.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_194.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_196.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_198.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_2.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_20.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_200.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_202.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_204.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_206.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_208.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_210.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_212.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_214.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_216.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_218.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_22.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_220.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_222.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_224.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_226.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_228.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_230.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_232.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_234.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_236.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_238.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_24.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_240.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_242.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_244.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_246.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_248.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_250.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_252.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_254.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_256.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_258.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_26.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_260.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_262.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_264.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_266.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_268.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_270.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_272.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_274.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_276.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_278.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_28.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_280.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_282.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_284.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_286.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_288.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_290.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_292.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_294.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_296.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_298.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_30.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_300.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_302.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_304.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_306.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_308.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_310.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_312.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_314.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_316.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_318.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_32.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_320.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_322.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_324.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_326.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_328.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_330.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_332.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_334.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_336.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_338.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_34.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_340.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_342.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_344.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_346.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_348.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_350.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_352.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_354.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_356.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_358.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_36.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_360.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_362.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_364.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_366.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_368.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_370.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_372.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_374.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_376.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_378.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_38.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_380.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_382.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_384.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_386.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_388.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_390.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_392.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_394.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_396.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_398.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_4.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_40.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_400.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_402.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_404.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_406.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_408.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_410.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_412.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_414.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_416.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_418.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_42.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_420.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_422.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_424.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_426.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_428.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_430.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_432.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_434.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_436.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_438.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_44.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_440.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_442.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_444.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_446.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_448.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_450.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_452.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_454.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_456.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_458.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_46.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_460.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_462.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_464.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_466.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_468.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_470.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_472.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_474.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_476.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_478.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_48.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_480.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_482.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_484.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_486.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_488.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_490.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_492.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_494.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_496.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_498.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_50.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_500.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_502.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_504.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_506.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_508.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_510.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_512.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_514.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_516.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_518.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_52.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_520.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_522.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_524.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_526.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_528.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_530.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_532.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_534.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_536.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_538.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_54.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_540.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_542.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_544.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_546.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_548.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_550.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_552.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_554.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_556.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_558.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_56.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_560.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_562.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_564.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_566.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_568.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_570.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_572.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_574.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_576.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_578.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_58.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_580.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_582.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_584.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_586.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_588.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_590.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_592.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_594.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_596.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_598.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_6.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_60.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_600.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_602.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_604.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_606.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_608.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_610.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_612.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_614.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_616.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_618.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_62.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_620.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_622.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_624.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_626.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_628.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_630.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_632.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_634.csv
# C:\Users\XWANG221\Downloads\Test_Flow_Trac\Flow1.csv_636.csv

# %%
Train_path = glob.glob('C:\\Users\\XWANG221\\Downloads\\Train_Flow_Trac\\*.csv')

X_all = np.empty((1, 50, 22))
Y_all = np.empty((1,))

for j in range(500):

    Flow = pd.read_csv(Train_path[j], usecols=['LatitudeWsu','GpsHeadingWsu','AxWsu','Flow','LaneDistanceLeft','LaneDistanceRight','LaneHeading','o1','o2','o6','o7','r1','r6','r7','rr6','rr7','t1','t6','t7','tt1','tt7','c1','c2'])
    Flow.fillna(10000000, inplace=True)
    
    Y_train = np.array(Flow['Flow'].values)
    X_train = np.array(Flow[['LatitudeWsu','GpsHeadingWsu','AxWsu','LaneDistanceLeft','LaneDistanceRight','LaneHeading','o1','o2','o6','o7','r1','r6','r7','rr6','rr7','t1','t6','t7','tt1','tt7','c1','c2']])

    dimof_output = 1
    dimof_input = X_train.shape[1]

    # Scale/whiten the X data
    scaler = StandardScaler()
    X_train = scaler.fit_transform(X_train)
  
    X, Y = create_dataset(X_train, Y_train, look_back=look_back)
    
    X_all = np.append(X_all, X, axis=0)
    Y_all = np.append(Y_all, Y, axis=0)

# %%
# These sizes need to be divisible by 32 and remove the first randomly created matrix.
Train_size = len(X_all)//64*64 + 1
Test_size = len(X_TestData)//64*64 + 1

Xtest = X_TestData[1:Test_size]
Ytest = Y_TestData[1:Test_size]

Xtrain = X_all[1:Train_size]
Ytrain = Y_all[1:Train_size]

# %%
# Create the LSTM network.
batch_size = 32
dropout = 0.5
num_epoch = 100
earlyStopping = EarlyStopping(monitor='val_loss', patience=0, verbose=0, mode='auto')
weights = {0:1, 1:1}

# %%
model_Flow = Sequential()
model_Flow.add(LSTM(output_dim=10, batch_input_shape=[batch_size, look_back, dimof_input]))
model_Flow.add(Dropout(dropout))
model_Flow.add(Dense(30, activation='relu'))
model_Flow.add(Dropout(dropout))
model_Flow.add(Dense(30, activation='relu'))
model_Flow.add(Dropout(dropout))
model_Flow.add(Dense(10, activation='relu'))
model_Flow.add(Dropout(dropout))
model_Flow.add(Dense(dimof_output, init='uniform', activation='sigmoid'))
model_Flow.compile(loss='binary_crossentropy', optimizer='adam',metrics=['accuracy'])

history = model_Flow.fit(
    Xtrain, Ytrain,
    class_weight=weights,
    validation_data=(Xtest, Ytest),
    callbacks=[earlyStopping],
    shuffle=True,
    nb_epoch=num_epoch, batch_size=batch_size, verbose=1)

print(history.history)

Y_predict = model_CutIn.predict_classes(Xtest, verbose=True)

# Add the prediction in a list
a6 = Y_predict.tolist()
# item[0] of the prediction is the predicted label
a26 = [item[0] for item in a6]
# the true label
b6 = Ytest.tolist()

# %%
nums_predict = [index for index, element in enumerate(a26) if element == 1]
p = sum((list(t) for t in zip(nums_predict, nums_predict[1:]) if t[0]+1 != t[1]), [])
p.insert(0,nums_predict[0])
p.append(nums_predict[-1])

nums_Y = [index for index, element in enumerate(b6) if element == 1]
y = sum((list(t) for t in zip(nums_Y, nums_Y[1:]) if t[0]+1 != t[1]), [])
y.insert(0,nums_Y[0])
y.append(nums_Y[-1])

big=0
small=0
same=0

for i in range(len(y)-1):
    if i % 2 == 0:
        for j in range(len(p)):
            if j % 2 == 0: 

                if (y[i] == p[j]) and (y[i+1] == p[j+1]):
                    same=same+1
                    j=j+2
                
                elif p[j]<=y[i] and p[j+1]>=y[i+1]:
                    big=big+1
                    j=j+2
                        
                elif p[j]>=y[i] and p[j+1]<=y[i+1]:
                    small=small+1
                    j=j+2
                    
                else:
                    j=j+2       
        i=i+2    

Predict = len(p)/2
Y = len(y)/2

def precision(n):
    fp = Predict-n
    prec = n/(n+fp)
    return prec

def recall(n):
    fn = Y-n
    rec = n/(n+fn)
    return rec
    
def conf(f):
    conf95 = []
    for i in range(len(y)):
        if i%2 == 0:
            c951=int(y[i]-f*(y[i+1]-y[i]))
            conf95.append(c951)
            conf95.append(y[i+1])
        
            c9522=y[i]+f*(y[i+1]-y[i])
            if float(c9522).is_integer()==True:
                conf95.append(c9522)
                conf95.append(y[i+1])
            else:
                con952 = int(c9522)+1
                conf95.append(con952)
                conf95.append(y[i+1])
        
            conf95.append(y[i])
            c9533=int(y[i+1]-f*(y[i+1]-y[i]))
            if float(c9533).is_integer()==True:
                conf95.append(c9533)
            else:
                c953 = int(c9533)+1
                conf95.append(c953)
            
            conf95.append(y[i])    
            c9544=y[i+1]+f*(y[i+1]-y[i])
            if float(c9544).is_integer()==True:
                conf95.append(c9544)
            else:
                con954 = int(c9544)+1
                conf95.append(con954)
        i=i+2
    return conf95

def result(rangelist):
    con95=0
    for i in range(len(p)):
        if i%2 == 0:
            for j in range(len(rangelist)-7):
                if j%8==0:
                    if (rangelist[j]<=p[i] and p[i+1]<=rangelist[j+1]) or (rangelist[j+2]<=p[i] and p[i+1]<=rangelist[j+3]) or (rangelist[j+4]<=p[i] and p[i+1]<=rangelist[j+5]) or (rangelist[j+6]<=p[i] and p[i+1]<=rangelist[j+7]):       
                        con95=con95+1
                        j=j+8
                    else:
                        j=j+8
            i=i+2
    return con95   
    
con95 = result(conf(0.05))
con90 = result(conf(0.1))          
con85 = result(conf(0.15))            
con80 = result(conf(0.2))

# %%
print("Predict:", Predict, "-", "True:", Y)   
print("big:",big, "-", "precision:", precision(big), "-", "recall:", recall(big))  
print("small:",small, "-", "precision:", precision(small), "-", "recall:", recall(small)) 
print("same:",same, "-", "precision:", precision(same), "-", "recall:", recall(same)) 
print("con95:",con95, "-", "precision:", precision(con95), "-", "recall:", recall(con95))  
print("con90:",con90, "-", "precision:", precision(con90), "-", "recall:", recall(con90)) 
print("con85:",con85, "-", "precision:", precision(con85), "-", "recall:", recall(con85)) 
print("con80:",con80, "-", "precision:", precision(con80), "-", "recall:", recall(con80))

# %% [markdown]
# # more 500

# %%
X_MoreTrainData = np.empty((1, 50, 22))
Y_MoreTrainData = np.empty((1,))

for j in range(450,500):
  
    Flow_more = pd.read_csv(Train_path[j], usecols=['LatitudeWsu','GpsHeadingWsu','AxWsu','Flow','LaneDistanceLeft','LaneDistanceRight','LaneHeading','o1','o2','o6','o7','r1','r6','r7','rr6','rr7','t1','t6','t7','tt1','tt7','c1','c2'])
    if Flow_more.shape[0] <= 50:
        pass
    else:
        Flow_more.fillna(10000000, inplace=True)
    
        Y_train_more = np.array(Flow_more['Flow'].values)
        X_train_more = np.array(Flow_more[['LatitudeWsu','GpsHeadingWsu','AxWsu','LaneDistanceLeft','LaneDistanceRight','LaneHeading','o1','o2','o6','o7','r1','r6','r7','rr6','rr7','t1','t6','t7','tt1','tt7','c1','c2']])
    
    # Scale/whiten the X data
        scaler = StandardScaler()
        X_train_more = scaler.fit_transform(X_train_more)
    
        X_more, Y_more = create_dataset(X_train_more, Y_train_more, look_back=look_back)
    
        X_MoreTrainData = np.append(X_MoreTrainData, X5, axis=0)
        Y_MoreTrainData = np.append(Y_MoreTrainData, Y5, axis=0)

# %%
# Added_size need to be divisible by 32 and remove the first randomly created matrix.
Added_size = len(X_MoreTrainData)//64*64+1

X_MoreTrainData = X_MoreTrainData[1:Added_size]
Y_MoreTrainData = Y_MoreTrainData[1:Added_size]

Xtrain = np.append(Xtrain, X_MoreTrainData, axis=0)
Ytrain = np.append(Ytrain, Y_MoreTrainData, axis=0)

# %%
model_Flow = Sequential()
model_Flow.add(LSTM(output_dim=10, batch_input_shape=[batch_size, look_back, dimof_input]))
model_Flow.add(Dropout(dropout))
model_Flow.add(Dense(30, activation='relu'))
model_Flow.add(Dropout(dropout))
model_Flow.add(Dense(30, activation='relu'))
model_Flow.add(Dropout(dropout))
model_Flow.add(Dense(10, activation='relu'))
model_Flow.add(Dropout(dropout))
model_Flow.add(Dense(dimof_output, init='uniform', activation='sigmoid'))
model_Flow.compile(loss='binary_crossentropy', optimizer='adam',metrics=['accuracy'])

history = model_Flow.fit(
    Xtrain, Ytrain,
    class_weight=weights,
    validation_data=(Xtest, Ytest),
    callbacks=[earlyStopping],
    shuffle=True,
    nb_epoch=num_epoch, batch_size=batch_size, verbose=1)

print(history.history)

Y_predict = model_CutIn.predict_classes(Xtest, verbose=True)

# Add the prediction in a list
a6 = Y_predict.tolist()
# item[0] of the prediction is the predicted label
a26 = [item[0] for item in a6]
# the true label
b6 = Ytest.tolist()
# Out:
# WARNING:tensorflow:From C:\Users\XWANG221\AppData\Local\Continuum\anaconda3\lib\site-packages\tensorflow\python\ops\resource_variable_ops.py:435: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# C:\Users\XWANG221\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:2: UserWarning: Update your `LSTM` call to the Keras 2 API: `LSTM(batch_input_shape=[32, 50, 2..., units=10)`
# WARNING:tensorflow:From C:\Users\XWANG221\AppData\Local\Continuum\anaconda3\lib\site-packages\tensorflow\python\ops\math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# C:\Users\XWANG221\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:10: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(1, activation="sigmoid", kernel_initializer="uniform")`
#   # Remove the CWD from sys.path while we load stuff.
# C:\Users\XWANG221\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:19: UserWarning: The `nb_epoch` argument in `fit` has been renamed `epochs`.
# Train on 48960 samples, validate on 61760 samples
# Epoch 1/100
# 48960/48960 [==============================] - 27s 545us/step - loss: 0.4710 - accuracy: 0.8746 - val_loss: 0.0657 - val_accuracy: 0.9994
# Epoch 2/100
# 48960/48960 [==============================] - 24s 494us/step - loss: 0.2657 - accuracy: 0.9238 - val_loss: 0.0346 - val_accuracy: 0.9997
# Epoch 3/100
# 48960/48960 [==============================] - 24s 497us/step - loss: 0.2124 - accuracy: 0.9346 - val_loss: 0.0230 - val_accuracy: 0.9997
# Epoch 4/100
# 48960/48960 [==============================] - 24s 492us/step - loss: 0.1967 - accuracy: 0.9375 - val_loss: 0.0183 - val_accuracy: 0.9997
# Epoch 5/100
# 48960/48960 [==============================] - 24s 493us/step - loss: 0.1872 - accuracy: 0.9394 - val_loss: 0.0157 - val_accuracy: 0.9997
# Epoch 6/100
# 48960/48960 [==============================] - 27s 543us/step - loss: 0.1730 - accuracy: 0.9443 - val_loss: 0.0143 - val_accuracy: 0.9997
# Epoch 7/100
# 48960/48960 [==============================] - 24s 496us/step - loss: 0.1542 - accuracy: 0.9545 - val_loss: 0.0128 - val_accuracy: 0.9997
# Epoch 8/100
# 48960/48960 [==============================] - 24s 495us/step - loss: 0.2069 - accuracy: 0.9312 - val_loss: 0.0139 - val_accuracy: 0.9997
# {'val_loss': [0.06569374849673539, 0.03458978675305345, 0.023012259472628135, 0.018253413170902944, 0.015681175439379733, 0.014261794440026763, 0.012842433402066249, 0.013946263553777774], 'val_accuracy': [0.9993685483932495, 0.9997409582138062, 0.9997247457504272, 0.9997247457504272, 0.9997409582138062, 0.9997409582138062, 0.9997247457504272, 0.9997247457504272], 'loss': [0.47097499900394013, 0.26574992792668684, 0.21237141770718534, 0.1966510381233069, 0.18724497398422435, 0.17297783737783046, 0.15423414275305822, 0.206891819460354], 'accuracy': [0.8745711, 0.9237541, 0.9345588, 0.93752044, 0.9393791, 0.9443219, 0.95449346, 0.93120915]}
# 61760/61760 [==============================] - 10s 169us/step

# %%
nums_predict = [index for index, element in enumerate(a26) if element == 1]
p = sum((list(t) for t in zip(nums_predict, nums_predict[1:]) if t[0]+1 != t[1]), [])
p.insert(0,nums_predict[0])
p.append(nums_predict[-1])

nums_Y = [index for index, element in enumerate(b6) if element == 1]
y = sum((list(t) for t in zip(nums_Y, nums_Y[1:]) if t[0]+1 != t[1]), [])
y.insert(0,nums_Y[0])
y.append(nums_Y[-1])

big=0
small=0
same=0

for i in range(len(y)-1):
    if i % 2 == 0:
        for j in range(len(p)):
            if j % 2 == 0: 

                if (y[i] == p[j]) and (y[i+1] == p[j+1]):
                    same=same+1
                    j=j+2
                
                elif p[j]<=y[i] and p[j+1]>=y[i+1]:
                    big=big+1
                    j=j+2
                        
                elif p[j]>=y[i] and p[j+1]<=y[i+1]:
                    small=small+1
                    j=j+2
                    
                else:
                    j=j+2       
        i=i+2    

Predict = len(p)/2
Y = len(y)/2

def precision(n):
    fp = Predict-n
    prec = n/(n+fp)
    if prec >=1:
        b=1
    else:
        b=prec
    return b

def recall(n):
    fn = Y-n
    rec = n/(n+fn)
    if rec >=1:
        a=1
    else:
        a=rec
    return a
    
def conf(f):
    conf95 = []
    for i in range(len(y)):
        if i%2 == 0:
            c951=int(y[i]-f*(y[i+1]-y[i]))
            conf95.append(c951)
            conf95.append(y[i+1])
        
            c9522=y[i]+f*(y[i+1]-y[i])
            if float(c9522).is_integer()==True:
                conf95.append(c9522)
                conf95.append(y[i+1])
            else:
                con952 = int(c9522)+1
                conf95.append(con952)
                conf95.append(y[i+1])
        
            conf95.append(y[i])
            c9533=int(y[i+1]-f*(y[i+1]-y[i]))
            if float(c9533).is_integer()==True:
                conf95.append(c9533)
            else:
                c953 = int(c9533)+1
                conf95.append(c953)
            
            conf95.append(y[i])    
            c9544=y[i+1]+f*(y[i+1]-y[i])
            if float(c9544).is_integer()==True:
                conf95.append(c9544)
            else:
                con954 = int(c9544)+1
                conf95.append(con954)
        i=i+2
    return conf95

def result(rangelist):
    con95=0
    for i in range(len(p)):
        if i%2 == 0:
            for j in range(len(rangelist)-7):
                if j%8==0:
                    if (rangelist[j]<=p[i] and p[i+1]<=rangelist[j+1]) or (rangelist[j+2]<=p[i] and p[i+1]<=rangelist[j+3]) or (rangelist[j+4]<=p[i] and p[i+1]<=rangelist[j+5]) or (rangelist[j+6]<=p[i] and p[i+1]<=rangelist[j+7]):       
                        con95=con95+1
                        #break
                        j=j+8
                    else:
                        j=j+8
            i=i+2
    return con95   

con95 = result(conf(0.05))
con90 = result(conf(0.1))          
con85 = result(conf(0.15))            
con80 = result(conf(0.2))

# %%
print("Predict:", Predict, "-", "True:", Y)   
print("big:",big, "-", "precision:", precision(big), "-", "recall:", recall(big))  
print("small:",small, "-", "precision:", precision(small), "-", "recall:", recall(small)) 
print("same:",same, "-", "precision:", precision(same), "-", "recall:", recall(same)) 
print("con95:",con95, "-", "precision:", precision(con95), "-", "recall:", recall(con95))  
print("con90:",con90, "-", "precision:", precision(con90), "-", "recall:", recall(con90)) 
print("con85:",con85, "-", "precision:", precision(con85), "-", "recall:", recall(con85)) 
print("con80:",con80, "-", "precision:", precision(con80), "-", "recall:", recall(con80))
